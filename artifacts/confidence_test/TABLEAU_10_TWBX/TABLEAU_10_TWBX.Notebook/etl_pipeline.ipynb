# %% [markdown]
# # ETL Pipeline — TABLEAU_10_TWBX
#
# This notebook ingests data from the original Tableau data sources
# into Fabric Lakehouse Delta tables.
#
# **Generated:** 2026-03-05 10:46
# **Source:** TableauToFabric migration tool

# %%
# ── Setup ──────────────────────────────────────────────
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
from datetime import datetime

# Fabric Lakehouse is automatically mounted
LAKEHOUSE_NAME = "TABLEAU_10_TWBX_Lakehouse"
print(f"ETL Pipeline started: {datetime.now()}")

# %% [markdown]
# ## Data Ingestion
#
# Loading 2 table(s) from source systems.

# %% [markdown]
# ### Table: `xy` (SQL Server)

# %%
# Read from SQL Server
jdbc_url = "jdbc:sqlserver://mssql2012.test.tsi.lan;databaseName=TestV1"
df_xy = spark.read \
    .format("jdbc") \
    .option("url", jdbc_url) \
    .option("dbtable", "xy") \
    .option("user", "<username>") \
    .option("password", "<password>") \
    .load()

# Preview
df_xy.printSchema()
print(f"Rows: {df_xy.count()}")

# Write to Lakehouse Delta table
df_xy.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("xy")
print(f"✓ Written to Lakehouse: xy")

# %% [markdown]
# ### Table: `Extract` (SQL Server)

# %%
# Read from SQL Server
jdbc_url = "jdbc:sqlserver://mssql2012.test.tsi.lan;databaseName=TestV1"
df_extract = spark.read \
    .format("jdbc") \
    .option("url", jdbc_url) \
    .option("dbtable", "Extract") \
    .option("user", "<username>") \
    .option("password", "<password>") \
    .load()

# Preview
df_extract.printSchema()
print(f"Rows: {df_extract.count()}")

# Write to Lakehouse Delta table
df_extract.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("extract")
print(f"✓ Written to Lakehouse: extract")

# %% [markdown]
# ## Summary

# %%
# ── Summary ────────────────────────────────────────────
print("\n" + "=" * 60)
print("ETL Pipeline Complete")
print("=" * 60)
print(f"Tables loaded: 2")
print(f"Completed: {datetime.now()}")

# List all Delta tables in Lakehouse
print("\nLakehouse tables:")
for t in spark.catalog.listTables():
    print(f"  - {t.name} ({t.tableType})")
