# %% [markdown]
# # ETL Pipeline — simple_report
#
# This notebook ingests data from the original Tableau data sources
# into Fabric Lakehouse Delta tables.
#
# **Generated:** 2026-03-05 10:12
# **Source:** TableauToFabric migration tool

# %%
# ── Setup ──────────────────────────────────────────────
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
from datetime import datetime

# Fabric Lakehouse is automatically mounted
LAKEHOUSE_NAME = "simple_report_Lakehouse"
print(f"ETL Pipeline started: {datetime.now()}")

# %% [markdown]
# ## Data Ingestion
#
# Loading 1 table(s) from source systems.

# %% [markdown]
# ### Table: `Sales` (SQL Server)

# %%
# Read from SQL Server
jdbc_url = "jdbc:sqlserver://sql-prod-01.contoso.com;databaseName=SalesDB"
df_sales = spark.read \
    .format("jdbc") \
    .option("url", jdbc_url) \
    .option("dbtable", "Sales") \
    .option("user", "<username>") \
    .option("password", "<password>") \
    .load()

# Preview
df_sales.printSchema()
print(f"Rows: {df_sales.count()}")

# Write to Lakehouse Delta table
df_sales.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("sales")
print(f"✓ Written to Lakehouse: sales")

# %% [markdown]
# ## Summary

# %%
# ── Summary ────────────────────────────────────────────
print("\n" + "=" * 60)
print("ETL Pipeline Complete")
print("=" * 60)
print(f"Tables loaded: 1")
print(f"Completed: {datetime.now()}")

# List all Delta tables in Lakehouse
print("\nLakehouse tables:")
for t in spark.catalog.listTables():
    print(f"  - {t.name} ({t.tableType})")
